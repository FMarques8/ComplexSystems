# %% [markdown]
# ## Project 2 - One-dimensional random walks
# ### Modelling of Complex Systems
# Francisco Marques 97639 franciscocmarques@ua.pt
#
# ### Results notebook
# #### File import

# %%
from p2_utils import *

# %% [markdown]
# ### Part 1 - One-dimensional symmetrical Random Walks
# #### Task 1.1
# Results from 3 RWs.

# %%
task1_1(3)

# %% [markdown]
# What about 10 RWs?

# %%
task1_1(10)

# %% [markdown]
# And lastly 20 RWs.

# %%
task1_1(20)

# %% [markdown]
# ### Task 1.2
# First with the given input arguments

# %%
T = [[40, 41], [400, 401], [4000, 4001]]
n = 50000

task1_2(T, n)
# Out:
# Probability condition: 0.9999999999999999
#
#             Mean 0: 0.002439999999999978
#
#             Variance [40, 41]: 40.8999140464
#
# Probability condition: 0.9999999999999999
#
#             Mean 0: 0.02475999999999967
#
#             Variance [400, 401]: 403.34718694240007
#
# Probability condition: 1.0
#
#             Mean 0: 0.16527999999999565
#
#             Variance [4000, 4001]: 3990.6500425216

# %% [markdown]
# Now with different inputs, first increasing the number of samples, and then increasing the number of jumps but decreasing the number of samples.

# %%
n = 100000

task1_2(T, n)
# Out:
# Probability condition: 1.0
#
#             Mean 0: 0.005709999999999995
#
#             Variance [40, 41]: 40.434707395900006
#
# Probability condition: 1.0
#
#             Mean 0: 0.018440000000000012
#
#             Variance [400, 401]: 399.2996999664
#
# Probability condition: 1.0
#
#             Mean 0: -0.022479999999998057
#
#             Variance [4000, 4001]: 3985.0535946496

# %%
n = 20000
T = [[50, 51], [500, 501], [5000, 5001], [50000, 50001]]

task1_2(T, n)
# Out:
# Probability condition: 1.0000000000000002
#
#             Mean 0: 0.00919999999999995
#
#             Variance [50, 51]: 50.60801536
#
# Probability condition: 1.0000000000000002
#
#             Mean 0: -0.1618499999999976
#
#             Variance [500, 501]: 500.2152045775
#
# Probability condition: 0.9999999999999999
#
#             Mean 0: 0.015450000000004849
#
#             Variance [5000, 5001]: 5003.9378612975
#
# Probability condition: 1.0
#
#             Mean 0: 0.7374500000000097
#
#             Variance [50000, 50001]: 50739.1833674975

# %% [markdown]
# ### Part 2 - One-dimensional random walks with a drift
# Again, first results with given input arguments and then we vary them.

# %%
T = [[40, 41], [400, 401], [4000, 4001]]
n = 50000
delta = 0.015

task2(T, n, delta)
# Out:
# Probability condition: 1.0
#
#             Mean 1.215: 1.22416
#
#             Variance [40, 41]: 40.682952294399996
#
# Probability condition: 1.0
#
#             Mean 12.015: 12.040859999999999
#
#             Variance [400, 401]: 397.9859304604
#
# Probability condition: 1.0
#
#             Mean 120.015: 119.98128
#
#             Variance [4000, 4001]: 3996.8532895616

# %% [markdown]
# Increase the drift constant (delta) and number of samples

# %%
n = 70000

for delta in [0.015, 0.07, 0.15]:
    task2(T, n, delta)
# Out:
# Probability condition: 1.0
#
#             Mean 1.215: 1.2217571428571428
#
#             Variance [40, 41]: 40.54196662673469
#
# Probability condition: 1.0
#
#             Mean 12.015: 12.072585714285715
#
#             Variance [400, 401]: 400.54881702836735
#
# Probability condition: 1.0
#
#             Mean 120.015: 119.95848571428571
#
#             Variance [4000, 4001]: 3971.9582194212244
# Probability condition: 1.0
#
#             Mean 5.67: 5.665114285714285
#
#             Variance [40, 41]: 39.830080129795924
#
# Probability condition: 1.0
#
#             Mean 56.07: 56.067785714285705
#
#             Variance [400, 401]: 392.9828622397959
#
# Probability condition: 0.9999999999999999
#
#             Mean 560.07: 559.9874
#
#             Variance [4000, 4001]: 3933.357069811429
# Probability condition: 1.0
#
#             Mean 12.15: 12.129057142857143
#
#             Variance [40, 41]: 36.73842996816326
#
# Probability condition: 1.0
#
#             Mean 120.15: 120.06955714285715
#
#             Variance [400, 401]: 363.70164751816327
#
# Probability condition: 1.0
#
#             Mean 1200.15: 1200.0503857142855
#
#             Variance [4000, 4001]: 3650.3156898512243
