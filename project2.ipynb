# %% [markdown]
# ## Project 2 - One-dimensional random walks
# ### Modelling of Complex Systems
# Francisco Marques 97639 franciscocmarques@ua.pt
#
# ### Results notebook
# #### File import

# %%
from p2_utils import *

# %% [markdown]
# ### Part 1 - One-dimensional symmetrical Random Walks
# #### Task 1.1
# Results from 3 RWs.

# %%
task1_1(3)

# %% [markdown]
# What about 10 RWs?

# %%
task1_1(10)

# %% [markdown]
# And lastly 20 RWs.

# %%
task1_1(20)

# %% [markdown]
# ### Task 1.2
# First with the given input arguments

# %%
T = [[40, 41], [400, 401], [4000, 4001]]
n = 50000

task1_2(T, n)
# Out:
# Probability condition: 0.9999999999999999
#
#             Mean 0: 0.03210000000000011
#
#             Variance [40, 41]: 40.60636958999999
#
# Probability condition: 1.0
#
#             Mean 0: 0.07775999999999961
#
#             Variance [400, 401]: 398.11271338240005
#
# Probability condition: 1.0
#
#             Mean 0: -0.03711999999999804
#
#             Variance [4000, 4001]: 3999.7535821056

# %% [markdown]
# Now with different inputs, first increasing the number of samples, and then increasing the number of jumps but decreasing the number of samples.

# %%
n = 100000

task1_2(T, n)
# Out:
# Probability condition: 1.0000000000000002
#
#             Mean 0: -0.018439999999999984
#
#             Variance [40, 41]: 40.16907996639999
#
# Probability condition: 1.0
#
#             Mean 0: -0.03196999999999939
#
#             Variance [400, 401]: 398.6383979191
#
# Probability condition: 1.0
#
#             Mean 0: 0.2058499999999981
#
#             Variance [4000, 4001]: 4007.4161857775

# %%
n = 20000
T = [[50, 51], [500, 501], [5000, 5001], [50000, 50001]]

task1_2(T, n)
# Out:
# Probability condition: 1.0
#
#             Mean 0: -0.06890000000000004
#
#             Variance [50, 51]: 50.64375279
#
# Probability condition: 1.0
#
#             Mean 0: 0.13185000000000002
#
#             Variance [500, 501]: 501.3472155775
#
# Probability condition: 0.9999999999999999
#
#             Mean 0: -0.06844999999999857
#
#             Variance [5000, 5001]: 4987.2637145975
#
# Probability condition: 1.0
#
#             Mean 0: -0.5108500000000049
#
#             Variance [50000, 50001]: 50015.9807322775

# %% [markdown]
# ### Part 2 - One-dimensional random walks with a drift
# Again, first results with given input arguments and then we vary them.

# %%
T = [[40, 41], [400, 401], [4000, 4001]]
n = 50000
delta = 0.015

task2(T, n, delta)
# Out:
# Probability condition: 1.0
#
#             Mean 1.215: 1.1984600000000003
#
#             Variance [40, 41]: 40.4132536284
#
# Probability condition: 1.0
#
#             Mean 12.015: 11.98638
#
#             Variance [400, 401]: 401.32501449560004
#
# Probability condition: 1.0
#
#             Mean 120.015: 119.91703999999999
#
#             Variance [4000, 4001]: 3999.5230376384

# %% [markdown]
# Increase the drift constant (delta) and number of samples

# %%
n = 70000

for delta in [0.015, 0.07, 0.15]:
    task2(T, n, delta)
# Out:
# Probability condition: 1.0
#
#             Mean 1.215: 1.2120857142857142
#
#             Variance [40, 41]: 40.32461964979592
#
# Probability condition: 1.0
#
#             Mean 12.015: 12.0715
#
#             Variance [400, 401]: 400.2839163214286
#
# Probability condition: 1.0
#
#             Mean 120.015: 120.29792857142856
#
#             Variance [4000, 4001]: 3999.0701242806126
# Probability condition: 1.0
#
#             Mean 5.67: 5.654414285714285
#
#             Variance [40, 41]: 39.52911337122449
#
# Probability condition: 1.0
#
#             Mean 56.07: 56.06491428571429
#
#             Variance [400, 401]: 392.2699861355102
#
# Probability condition: 1.0000000000000002
#
#             Mean 560.07: 559.9677285714286
#
#             Variance [4000, 4001]: 3930.9686728406123
# Probability condition: 1.0000000000000002
#
#             Mean 12.15: 12.159071428571428
#
#             Variance [40, 41]: 36.974896280612256
#
# Probability condition: 1.0
#
# ...
