# %% [markdown]
# ### Project 1 results and plots
#
# Importing the utils.py file that contains all of the functions needed

# %%
from p1_utils import * # wildcard operator to skip using the suffix 'utils.'

# %% [markdown]
# ## Part 1
# ### Task 1.2

# %%
task1_2()
# Out:
# 100 trials
# Theoretical average: 50.5, Numerical average: 50.0538
# Theoretical variance: 833.25, Numerical variance: 820.74855
# Theoretical probability: 0.59596, Numerical probability: 0.595
#
# 10000 trials
# Theoretical average: 50.5, Numerical average: 50.50136
# Theoretical variance: 833.25, Numerical variance: 824.78665
# Theoretical probability: 0.59596, Numerical probability: 0.59862
#
# 1000000 trials
# Theoretical average: 50.5, Numerical average: 50.49793
# Theoretical variance: 833.25, Numerical variance: 824.87654
# Theoretical probability: 0.59596, Numerical probability: 0.60002

# %% [markdown]
# We can see that the numerical values are very close to the expected results.

# %% [markdown]
# ### Task 1.3.

# %%
task1_3(1000)
# Out:
# Theoretical results
# Mean of x: 0.5
# Mean of y: 0.5
# Mean of z: 0.25
# 100 trials
# Mean of x: 0.49944
# Mean of y: 0.5011
# Mean of z: 0.2506
#
# 10000 trials
# Mean of x: 0.49987
# Mean of y: 0.50003
# Mean of z: 0.24998
#
# 1000000 trials
# Mean of x: 0.5
# Mean of y: 0.5
# Mean of z: 0.25

# %% [markdown]
# ## Part 2
# ### Task 2.1

# %%
task2_1()

# %% [markdown]
# The line is at the expected count value, which is given by $\frac{N}{\text{number of bins}}=N\times\Delta x$, however as this is an uniform distribution between [0,1], the bar is at $y = 1$. The blue line is a kernel density estimate to smooth the histogram.

# %% [markdown]
# ### Task 2.2

# %%
print('Expected mean value: 0.5')
print(f'Expected variance: {1/12}')


task2_2()
# Out:
# Expected mean value: 0.5
# Expected variance: 0.08333333333333333
# 100 samples
# Mean of x: 0.47817
# Variance of x: 0.07265
# 10000 samples
# Mean of x: 0.50262
# Variance of x: 0.08332
# 1000000 samples
# Mean of x: 0.5002
# Variance of x: 0.0833

# %% [markdown]
# ### Task 2.3

# %%
task2_3()

# %% [markdown]
# Once again, the red line represents the function $Q(y)=2y$, which show us that the probability density distribution function is correct.

# %% [markdown]
# ## Part 3

# %%
task3()
# Out:
# 10 samples
# Normalization condition value: 1.0
# Mean of Y: 0.50073
# Variance of Y: 0.00844
# Mean of x: 0.50073
# Variance of x: 0.08341
# sigma^2/n: 0.00834, variance of Y: 0.00844
# 100 samples
# Normalization condition value: 1.0
# Mean of Y: 0.49942
# Variance of Y: 0.00084
# Mean of x: 0.49945
# Variance of x: 0.08328
# sigma^2/n: 0.00083, variance of Y: 0.00084
# 1000 samples
# Normalization condition value: 1.0
# Mean of Y: 0.49974
# Variance of Y: 9e-05
# Mean of x: 0.49975
# Variance of x: 0.08333
# sigma^2/n: 8e-05, variance of Y: 9e-05

# %% [markdown]
# ## Part 4

# %%
throwing_balls()
# Out:
# 100 samples
# Number of attempts with at least 1 ball in box 3: 94
# Probability of finding at least 1 ball in box 3: 0.94
# Probability of finding 3 balls in box 3: 0.19
# 10000 samples
# Number of attempts with at least 1 ball in box 3: 9135
# Probability of finding at least 1 ball in box 3: 0.9135
# Probability of finding 3 balls in box 3: 0.2124
# 1000000 samples
# Number of attempts with at least 1 ball in box 3: 915278
# Probability of finding at least 1 ball in box 3: 0.915278
# Probability of finding 3 balls in box 3: 0.219053
