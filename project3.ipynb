# %%
# install dependencies
# %pip install numpy
# %pip install matplotlib
# %matplotlib inline
# %pip install seaborn

# import functions
from p3_utils import *
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Part 1
# ## Task 1.1

# %%
task1_1(n = 3)

# %% [markdown]
# ## Task 1.2
# Takes a very long time to compute for the suggested values, so different values will be shown.

# %%
task1_2([50, 51], 10000)
# Out:
# Probability condition: 1.0
#
#         Mean 0: 5e-05 = -5e-05
#
#         Variance 50.5: 50.227000000000004
#
# ...

# %%
task1_2([500, 501], 10000)
# Out:
# Probability condition: 1.0
#
#         Mean 0: 0.0007 = 0.00019999999999999998
#
#         Variance 500.5: 501.70910000000003
#
# ...

# %%
task1_2([5000, 5001], 1000)
# Out:
# Probability condition: 0.9999999999999999
#
#         Mean 0: 0.0135 = -0.001
#
#         Variance 5000.5: 5052.647000000001
#
# ...

# %% [markdown]
# # Part 2
# ## Task 2.1

# %%
task2_1(100000)

# %% [markdown]
# # Part 3
# ## Task 3.1

# %%
task3_1()

# %% [markdown]
# ## Task 3.2

# %%
task3_2([1.6, 2])
